# %%
import duckdb
from sqlalchemy import create_engine
import pandas as pd

# %%
# Dataset connection
df = pd.read_csv('/Users/jinlinchen/Documents/Study/HWR Berlin/Semester 2/Analytics Lab/Analytics Project/Dataset part/preprocessed_data.csv')

# %%
# Database connection
# Open database can check your connection settings (Host --> path) 
# make sure to close your dbeaver or error might occur, or make a copy of your database
db_connection_string = '/Users/jinlinchen/Documents/Study/HWR Berlin/Semester 2/Analytics Lab/Data Resource/isrecon_AIS11.duckdb'
conn = duckdb.connect(db_connection_string)

# %%
# List all tables in the database
tables = conn.execute("SHOW TABLES").fetchdf()
print(tables)
# Out:
#             name
# 0        authors
# 1      citations
# 2       entities
# 3   entity_count
# 4       keywords
# 5       ontology
# 6         papers
# 7     paragraphs
# 8      sentences
# 9        sources
# 10   subsections
# 11      synonyms

# %%
# Query the database to join entities and paragraphs on para_id
query = """
SELECT e.entity, e.sentence, p.paragraph, s.sentence_original
FROM entities e
JOIN paragraphs p ON e.para_id = p.para_id
JOIN sentences s ON e.sentence_id = s.sentence_id
"""
db_data = conn.execute(query).fetchdf()

# %%
# Check database data
db_data
# Out:
#                      entity  \
# 0        product innovation
# 1           decision-making
# 2         business strategy
# 3         platform strategy
# 4            Salesforce.com
# ...                     ...
# 4654131             privacy
# 4654132       IT management
# 4654133  chisquare = 588.36
# 4654134       IT governance
# 4654135           algorithm
#
#                                                   sentence  \
# 0        A B S T R A C TFirm - sponsored online user co...
# 1        In addition to potentially improving customer ...
# 2        Firms across industries , especially in the hi...
# 3        SAP , for example , has implemented its OUC ( ...
# 4        Examples of other well - known OUC include Sal...
# ...                                                    ...
# 4654131  According to Varian , people agree to the ' in...
# 4654132  Comparing IT governance and IT management , ST...
# 4654133  The test produced poor model fit statistics ( ...
# 4654134  Comparing IT governance and IT management , ST...
# 4654135  A genetic algorithm formulation of the problem...
#
#                                                  paragraph  \
# 0        Abstract. Firm-sponsored online user communiti...
# 1        Firm-hosted online user communities (hereinaft...
# 2        Firm-hosted online user communities (hereinaft...
# 3        Firm-hosted online user communities (hereinaft...
# 4        Firm-hosted online user communities (hereinaft...
# ...                                                    ...
# 4654131  The last stage of the laboring society, the so...
# 4654132  Preposition 2: There may be a deficit in those...
# 4654133  In terms of ex post approaches, we ran Harman'...
# 4654134  Preposition 2: There may be a deficit in those...
# 4654135  A genetic algorithm formulation of the problem...
#
#                                          sentence_original
# 0        Abstract. Firm-sponsored online user communiti...
# 1        In addition to potentially improving customer ...
# 2        Firms across industries, especially in the hig...
# 3        SAP, for example, has implemented its OUC (SAP...
# 4        Examples of other well-known OUC include Sales...
# ...                                                    ...
# 4654131  According to Varian, people agree to the 'inva...
# 4654132  Comparing IT governance and IT management, Pet...
# 4654133  The test produced poor model fit statistics (c...
# 4654134  Comparing IT governance and IT management, Pet...
# 4654135  A genetic algorithm formulation of the problem...
#
# [4654136 rows x 4 columns]

# %%
#check initial dataset
df.head()
# Out:
#       ID                entity                     ent_id  \
# 0  90812            interviews      qualitative interview
# 1  90770  knowledge management       knowledge management
# 2  90500       reference model        reference modelling
# 3  90417                   UML  unified modeling language
# 4  90361    reference modeling        reference modelling
#
#                                    sentence_original  class_ID  \
# 0  Especially for the problem of reduced identity...         1
# 1  This makes it challenging for them to organize...         3
# 2  It can be foreseen that managing such a compre...         3
# 3  In particular, redefinition in UML allows one ...         3
# 4  At the same time, redundancy in a reference mo...         2
#
#                class_name    sentence_id  \
# 0      belongs_to_article  507_6563_6594
# 1  background_information  507_4787_4813
# 2  background_information  505_7541_7567
# 3  background_information  505_4085_4121
# 4            related_work  505_2464_2508
#
#                                sentence_preprocessed  \
# 0  especially problem reduced identity efforts vt...
# 1  makes challenging organize meetings conversati...
# 2  foreseen managing comprehensive reference mode...
# 3  particular redefinition uml allows one modify ...
# 4  time redundancy reference model typically avoi...
#
#                                     sentence_stemmed  \
# 0  especi problem reduc ident effort vt identifi ...
# 1  make challeng organ meet convers well perform ...
# 2  foreseen manag comprehens refer model challeng...
# 3  particular redefinit uml allow on modifi data ...
# 4  time redund refer model typic avoid see e g co...
#
#                                      sentence_lemmas  \
# 0  especially problem reduce identity effort vt i...
# 1  make challenge organize meeting conversation w...
# 2  foresee manage comprehensive reference model c...
# 3  particular redefinition uml allow one modify d...
# 4  time redundancy reference model typically avoi...
#
#                                   sentence_tokenized
# 0  ['especially', 'problem', 'reduced', 'identity...
# 1  ['makes', 'challenging', 'organize', 'meetings...
# 2  ['fore', '##see', '##n', 'managing', 'comprehe...
# 3  ['particular', 'red', '##ef', '##ini', '##tion...
# 4  ['time', 'red', '##unda', '##ncy', 'reference'...

# %%
# Filter out the duplicates, because we want to have examples where the same sentence is annotated with different entities.
duplicates = db_data[db_data.duplicated(subset=['sentence_original'], keep=False)]
duplicates_with_diff_entities = duplicates[duplicates.duplicated(subset=['sentence_original'], keep=False)]

# %%
# Descending order on column 'sentence_original'
duplicates_with_diff_entities = duplicates_with_diff_entities.sort_values(by='sentence_original', ascending=False)

# %%
# Check the result
duplicates_with_diff_entities
# Out:
#                                entity  \
# 340820                     algorithms
# 342460                 data warehouse
# 2786156                     algorithm
# 2787155                     algorithm
# 3042165                    Hypothesis
# ...                               ...
# 375218                       theories
# 370084   information systems research
# 456931                       theories
# 4603673                            IT
# 4603017              consulting firms
#
#                                                   sentence  \
# 340820   ➢ Using the data warehouse as an infrastructur...
# 342460   ➢ Using the data warehouse as an infrastructur...
# 2786156  ➢ Logic errors are incorrect formulas due to c...
# 2787155  ➢ Logic errors are incorrect formulas due to c...
# 3042165  ✗ END_PARAGRAPH_TAG START_PARAGRAPH_TAG Hypoth...
# ...                                                    ...
# 375218    Add theories for e - government to the knowl...
# 370084    Add theories for e - government to the knowl...
# 456931    Add theories for e - government to the knowl...
# 4603673   ...
# 4603017   ...
#
#                                                  paragraph  \
# 340820   ➢ Coupling the data warehousing approaches and...
# 342460   ➢ Coupling the data warehousing approaches and...
# 2786156  ➢ Mechanical errors are typing errors, pointin...
# 2787155  ➢ Mechanical errors are typing errors, pointin...
# 3042165  ✗ ✓ Hypothesis supported, (✓) Hypothesis parti...
# ...                                                    ...
# 375218    Perform in-depth discussions and analyses of ...
# 370084    Perform in-depth discussions and analyses of ...
# 456931    Perform in-depth discussions and analyses of ...
# 4603673      Five established IT consulting firms were ...
# 4603017      Five established IT consulting firms were ...
#
#                                          sentence_original
# 340820   ➢ Using the data warehouse as an infrastructur...
# 342460   ➢ Using the data warehouse as an infrastructur...
# 2786156  ➢ Logic errors are incorrect formulas due to c...
# 2787155  ➢ Logic errors are incorrect formulas due to c...
# 3042165  ✗ ✓ Hypothesis supported, (✓) Hypothesis parti...
# ...                                                    ...
# 375218    Add theories for e-government to the knowledg...
# 370084    Add theories for e-government to the knowledg...
# 456931    Add theories for e-government to the knowledg...
# 4603673      Five established IT consulting firms were ...
# 4603017      Five established IT consulting firms were ...
#
# [3425410 rows x 4 columns]

# %%
# Remove duplicates where the sentence does not start with a letter
import string
def starts_with_letter(sentence):
    return sentence.strip()[0].lower() in string.ascii_lowercase
filtered_duplicates = duplicates_with_diff_entities[duplicates_with_diff_entities['sentence_original'].apply(starts_with_letter)]

# %%
#check
filtered_duplicates
# Out:
#                                entity  \
# 681178                    mean of 500
# 685069                    mean of 500
# 678387             moderator variable
# 3919500                  web services
# 3920064            process management
# ...                               ...
# 375218                       theories
# 370084   information systems research
# 456931                       theories
# 4603673                            IT
# 4603017              consulting firms
#
#                                                   sentence  \
# 681178   zy refers to the mean of 500 path estimates fr...
# 685069   zy refers to the mean of 500 path estimates fr...
# 678387   zy refers to the mean of 500 path estimates fr...
# 3919500  zur Muehlen et al . examined the development o...
# 3920064  zur Muehlen et al . examined the development o...
# ...                                                    ...
# 375218    Add theories for e - government to the knowl...
# 370084    Add theories for e - government to the knowl...
# 456931    Add theories for e - government to the knowl...
# 4603673   ...
# 4603017   ...
#
#                                                  paragraph  \
# 681178   xy refers to the mean of 500 path estimates fr...
# 685069   xy refers to the mean of 500 path estimates fr...
# 678387   xy refers to the mean of 500 path estimates fr...
# 3919500  . zur Muehlen et al. examined the development ...
# 3920064  . zur Muehlen et al. examined the development ...
# ...                                                    ...
# 375218    Perform in-depth discussions and analyses of ...
# 370084    Perform in-depth discussions and analyses of ...
# 456931    Perform in-depth discussions and analyses of ...
# 4603673      Five established IT consulting firms were ...
# 4603017      Five established IT consulting firms were ...
#
#                                          sentence_original
# 681178   zy refers to the mean of 500 path estimates fr...
# 685069   zy refers to the mean of 500 path estimates fr...
# 678387   zy refers to the mean of 500 path estimates fr...
# 3919500  zur Muehlen et al. examined the development of...
# 3920064  zur Muehlen et al. examined the development of...
# ...                                                    ...
# 375218    Add theories for e-government to the knowledg...
# 370084    Add theories for e-government to the knowledg...
# 456931    Add theories for e-government to the knowledg...
# 4603673      Five established IT consulting firms were ...
# 4603017      Five established IT consulting firms were ...
#
# [3312813 rows x 4 columns]

# %%
# Filter out the duplicates, because we want to have examples where the same sentence is annotated with different entities.
filtered_duplicates = filtered_duplicates.drop_duplicates(subset=['entity', 'sentence_original'])

# %%
# check result
filtered_duplicates
# Out:
#                                entity  \
# 681178                    mean of 500
# 678387             moderator variable
# 3919500                  web services
# 3920064            process management
# 67939                             CIO
# ...                               ...
# 377216                 knowledge base
# 375218                       theories
# 370084   information systems research
# 4603673                            IT
# 4603017              consulting firms
#
#                                                   sentence  \
# 681178   zy refers to the mean of 500 path estimates fr...
# 678387   zy refers to the mean of 500 path estimates fr...
# 3919500  zur Muehlen et al . examined the development o...
# 3920064  zur Muehlen et al . examined the development o...
# 67939    zooming in on the two directions of understand...
# ...                                                    ...
# 377216    Add theories for e - government to the knowl...
# 375218    Add theories for e - government to the knowl...
# 370084    Add theories for e - government to the knowl...
# 4603673   ...
# 4603017   ...
#
#                                                  paragraph  \
# 681178   xy refers to the mean of 500 path estimates fr...
# 678387   xy refers to the mean of 500 path estimates fr...
# 3919500  . zur Muehlen et al. examined the development ...
# 3920064  . zur Muehlen et al. examined the development ...
# 67939    zooming in on the two directions of understand...
# ...                                                    ...
# 377216    Perform in-depth discussions and analyses of ...
# 375218    Perform in-depth discussions and analyses of ...
# 370084    Perform in-depth discussions and analyses of ...
# 4603673      Five established IT consulting firms were ...
# 4603017      Five established IT consulting firms were ...
#
#                                          sentence_original
# 681178   zy refers to the mean of 500 path estimates fr...
# 678387   zy refers to the mean of 500 path estimates fr...
# 3919500  zur Muehlen et al. examined the development of...
# 3920064  zur Muehlen et al. examined the development of...
# 67939    zooming in on the two directions of understand...
# ...                                                    ...
# 377216    Add theories for e-government to the knowledg...
# 375218    Add theories for e-government to the knowledg...
# 370084    Add theories for e-government to the knowledg...
# 4603673      Five established IT consulting firms were ...
# 4603017      Five established IT consulting firms were ...
#
# [2693350 rows x 4 columns]

# %%
# Save the first 1000 examples
filtered_1000 = filtered_duplicates.head(1000)

# %%
# check result
filtered_1000
# Out:
#                                entity  \
# 681178                    mean of 500
# 678387             moderator variable
# 3919500                  web services
# 3920064            process management
# 67939                             CIO
# ...                               ...
# 2320388                           app
# 2148129  principal component analysis
# 2146735                           PCA
# 1964449                    mean value
# 2121086                        e-book
#
#                                                   sentence  \
# 681178   zy refers to the mean of 500 path estimates fr...
# 678387   zy refers to the mean of 500 path estimates fr...
# 3919500  zur Muehlen et al . examined the development o...
# 3920064  zur Muehlen et al . examined the development o...
# 67939    zooming in on the two directions of understand...
# ...                                                    ...
# 2320388  where β 01 and β 02 are the fixed intercepts ,...
# 2148129  where α , β , γ , and δ are different weights ...
# 2146735  where α , β , γ , and δ are different weights ...
# 1964449  where α j denotes the shared frailty of consum...
# 2121086  where α j denotes the shared frailty of consum...
#
#                                                  paragraph  \
# 681178   xy refers to the mean of 500 path estimates fr...
# 678387   xy refers to the mean of 500 path estimates fr...
# 3919500  . zur Muehlen et al. examined the development ...
# 3920064  . zur Muehlen et al. examined the development ...
# 67939    zooming in on the two directions of understand...
# ...                                                    ...
# 2320388  where β 01 and β 02 are the fixed intercepts, ...
# 2148129  where α, β, γ, and δ are different weights of ...
# 2146735  where α, β, γ, and δ are different weights of ...
# 1964449  where α j denotes the shared frailty of consum...
# 2121086  where α j denotes the shared frailty of consum...
#
#                                          sentence_original
# 681178   zy refers to the mean of 500 path estimates fr...
# 678387   zy refers to the mean of 500 path estimates fr...
# 3919500  zur Muehlen et al. examined the development of...
# 3920064  zur Muehlen et al. examined the development of...
# 67939    zooming in on the two directions of understand...
# ...                                                    ...
# 2320388  where β 01 and β 02 are the fixed intercepts, ...
# 2148129  where α, β, γ, and δ are different weights of ...
# 2146735  where α, β, γ, and δ are different weights of ...
# 1964449  where α j denotes the shared frailty of consum...
# 2121086  where α j denotes the shared frailty of consum...
#
# [1000 rows x 4 columns]

# %%
# Save the first 1000 examples to a csv file for manual labeling. 
csv_file_path = '/Users/jinlinchen/Documents/Study/HWR Berlin/Semester 2/Analytics Lab/Analytics Project/Database Part/manual_check.csv'
filtered_1000.to_csv(csv_file_path, index=False)

# %% [markdown]
# 250 are labeled by each team member.

# %%
# Load the manually labeled data
df_manual = pd.read_csv('/Users/jinlinchen/Documents/Study/HWR Berlin/Semester 2/Analytics Lab/Analytics Project/Database Part/manual_label - consolidated.csv')
